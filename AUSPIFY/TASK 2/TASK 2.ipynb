# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("clean_dataset.csv")
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country  date_added  release_year rating  duration  \
# 0  United States  2021-09-25          2020  PG-13    90 min
# 1         France  2021-09-24          2021  TV-MA  1 Season
# 2  United States  2021-09-24          2021  TV-MA  1 Season
# 3         Brazil  2021-09-22          2021  TV-PG    91 min
# 4  United States  2021-09-24          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
print("\nContent Type:")
print(df["type"].value_counts())

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x="type")
plt.title("Netflix Content Distribution")
plt.xlabel("Type")
plt.ylabel("Number of Titles")
plt.show()
# Out:
# Content Type:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
print("\nTop 10 Countries:")
print(df["country"].value_counts().head(10))

plt.figure(figsize=(10, 5))
df["country"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Countries by Number of Titles")
plt.xlabel("Country")
plt.ylabel("Number of Titles")
plt.xticks(rotation=45)
plt.show()
# Out:
# Top 10 Countries:
# country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
# Canada             271
# Japan              259
# South Korea        214
# France             213
# Spain              182
# Name: count, dtype: int64

# %%
print("\nTop 10 Categories:")
print(df["listed_in"].value_counts().head(10))

plt.figure(figsize=(10, 5))
df["listed_in"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Netflix Categories")
plt.xlabel("Category")
plt.ylabel("Number of Titles")
plt.xticks(rotation=45)
plt.show()
# Out:
# Top 10 Categories:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            219
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: count, dtype: int64

# %%
year_count = df["release_year"].value_counts().sort_index()

plt.figure(figsize=(10, 5))
plt.plot(year_count.index, year_count.values)
plt.title("Netflix Content by Release Year")
plt.xlabel("Release Year")
plt.ylabel("Number of Titles")
plt.show()

# %% [markdown]
# ## Task 2 — Summary of Findings
# The Netflix dataset contains both Movies and TV Shows.
#
# Movies make up a larger portion of the dataset than TV Shows.
#
# The country analysis shows that a few countries contribute a large number of Netflix titles, with the United States being one of the major contributors.
#
# The dataset contains a wide variety of categories, with Drama, International Movies, and Comedies among the commonly occurring categories.
#
# The number of Netflix titles increased significantly in the more recent release years, showing strong growth in content over time.
#
# Overall, the EDA shows that Netflix has a large and diverse content library, with movies dominating and substantial growth in newer content.
